# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
laptop_data = pd.read_csv('laptop_details.csv')
laptop_data.head()
# Out:
#                                                title    price  \
# 0  Lenovo 15.6" Laptop, IdeaPad 1, 20GB RAM, 1TB ...  $429.00
# 1  HP 2022 Newest Pavilion 15.6" HD Laptop, Intel...  $469.00
# 2  SGIN Laptop 15.6 Inch, 4GB DDR4 128GB SSD Wind...  $259.98
# 3  HP 2021 Stream 14" HD SVA Laptop Computer, Int...  $259.99
# 4  SGIN Laptop 12GB RAM 512GB SSD, 15.6 Inch Wind...  $359.99
#
#                rating   brand model_name  screen_size hard_disk_size  \
# 0  4.3 out of 5 stars  Lenovo    IdeaPad  15.6 Inches           1 TB
# 1  4.3 out of 5 stars      HP        NaN  15.6 Inches           1 TB
# 2  4.4 out of 5 stars    SGIN        NaN  15.6 Inches         128 GB
# 3  4.2 out of 5 stars      HP        NaN    14 Inches          64 GB
# 4  4.3 out of 5 stars    SGIN        NaN  15.6 Inches         512 GB
#
#        cpu_model ram_memory_installed_size operating_system  \
# 0         Athlon                     20 GB       Windows 11
# 1  Pentium N5000                     16 GB       Windows 11
# 2        Celeron                      4 GB       Windows 11
# 3      Celeron N                      4 GB     Windows 10 S
# 4        Celeron                     12 GB              NaN
#
#       special_feature graphics_card_description graphics_coprocessor  \
# 0          Anti-glare                Integrated  AMD Radeon Graphics
# 1  Anti Glare Coating                       NaN   Intel UHD Graphics
# 2                 NaN                       NaN           Integrated
# 3          Anti-glare                       NaN                  NaN
# 4                 NaN                       NaN           Integrated
#
#      series card_description color cpu_speed hard_disk_description resolution
# 0       NaN              NaN   NaN       NaN                   NaN        NaN
# 1  Pavilion       Integrated   NaN       NaN                   NaN        NaN
# 2       NaN       Integrated  Gray   2.5 GHz                   NaN        NaN
# 3        HP       Integrated  Pink       NaN                   NaN        NaN
# 4       NaN       Integrated   NaN   2.9 GHz                   SSD      1080p

# %%
laptop_data.columns
# Out:
# Index(['title', 'price', 'rating', 'brand', 'model_name', 'screen_size',
#        'hard_disk_size', 'cpu_model', 'ram_memory_installed_size',
#        'operating_system', 'special_feature', 'graphics_card_description',
#        'graphics_coprocessor', 'series', 'card_description', 'color',
#        'cpu_speed', 'hard_disk_description', 'resolution'],
#       dtype='object')

# %%
Laptop_Name_dim = laptop_data[['title','brand', 'model_name']]
Laptop_Name_dim['Laptop_Name_id'] = Laptop_Name_dim.index
Laptop_Name_dim
# Out:
#                                                 title          brand  \
# 0   Lenovo 15.6" Laptop, IdeaPad 1, 20GB RAM, 1TB ...         Lenovo
# 1   HP 2022 Newest Pavilion 15.6" HD Laptop, Intel...             HP
# 2   SGIN Laptop 15.6 Inch, 4GB DDR4 128GB SSD Wind...           SGIN
# 3   HP 2021 Stream 14" HD SVA Laptop Computer, Int...             HP
# 4   SGIN Laptop 12GB RAM 512GB SSD, 15.6 Inch Wind...           SGIN
# 5   Lenovo 15.6" Laptop, IdeaPad 1, 20GB RAM, 1TB ...         Lenovo
# 6   HP 2022 Newest Pavilion 15.6" HD Laptop, Intel...             HP
# 7   Lenovo IdeaPad 1i Multitasking Laptop, 14" HD ...         Lenovo
# 8   2022 HP Pavilion 17 Laptop, 17.3" HD+ Touch Di...             HP
# 9   Lenovo 14" IdeaPad 1 Laptop, Intel Dual-core P...         Lenovo
# 10  HP Laptop 14-DQ3025CL 14" Intel Pentium Silver...             HP
# 11  HP Chromebook Laptop 14a-na1043cl 14" Diagonal...             HP
# 12  Acer Chromebook Spin 311 Convertible Laptop, I...           Acer
# 13  Fast Dell Latitude E5470 HD Business Laptop No...           Dell
# 14  HP 15.6in Laptop (Intel Pentium Quad-Core N500...             HP
# 15  Microsoft Surface Laptop Go - 12.4" Touchscree...      Microsoft
# 16  Dell Latitude E7470 14in Laptop, Core i5-6300U...           Dell
# 17  Lenovo 2022 Newest Ideapad 3 Laptop, 15.6" HD ...         Lenovo
# 18  ASUS Chromebook Vibe C55 Flip, Cloud Gaming La...           ASUS
# 19  Apple 2020 MacBook Air Laptop M1 Chip, 13" Ret...          Apple
# 20  Acer Aspire 5 A515-56-347N Slim Laptop - 15.6"...           Acer
# 21  Gateway Newest Touchscreen 11.6 HD 2-in-1 Conv...        Gateway
# 22  Lenovo ThinkBook 15 Gen 3 15.6" FHD (36GB DDR4...  Ist computers
# 23  Lenovo 2022 IdeaPad 1 15.6" HD Laptop, Athlon ...         Lenovo
# 24  ASUS Vivobook Laptop L210 11.6" Ultra Thin Lap...           ASUS
# 25  Lenovo IdeaPad 1 14 Laptop, 14.0" HD Display, ...         Lenovo
# 26  Samsung Chromebook 4 (2021 Model) 11.6" Intel ...        SAMSUNG
# 27  Gateway 15.6 HD Ultra Slim Notebook in Navy Bl...        Gateway
# 28  Lenovo IdeaPad 1i Multitasking Laptop, 14" HD ...         Lenovo
# 29  HP 17 Laptop, 17.3” HD+ Display, 11th Gen Inte...             HP
# 30  SGIN 17 Inch Laptop, Windows 11 Laptops with I...           SGIN
# 31  HP Newest 14" Thin Light Laptop, Intel Dual-Co...             HP
# 32  Lenovo IdeaPad 15.6" Laptop Newest, 20GB RAM, ...         Lenovo
#
#                      model_name  Laptop_Name_id
# 0                       IdeaPad               0
# 1                           NaN               1
# 2                           NaN               2
# 3                           NaN               3
# 4                           NaN               4
# 5                           NaN               5
# 6                      Pavilion               6
# 7                           NaN               7
# 8                           NaN               8
# 9                     IdeaPad 1               9
# 10                          NaN              10
# 11                          NaN              11
# 12          Chromebook Spin 311              12
# 13          Dell Latitude E5470              13
# 14                   HP-15.6-RP              14
# 15            Surface Laptop Go              15
# 16                          NaN              16
# 17                          NaN              17
# 18                          NaN              18
# 19                  MacBook Air              19
# 20                 A515-56-347N              20
# 21  2-in-1 Convertible Notebook              21
# 22                          NaN              22
# 23                          NaN              23
# 24          ASUS Vivobook Go 12              24
# 25                          NaN              25
# 26                 Chromebook 4              26
# 27                    GA15HD-BL              27
# 28                          NaN              28
# 29             TPN-I139_320M3AV              29
# 30                          NaN              30
# 31                          NaN              31
# 32                      Ideapad              32

# %%
laptop_feature_dim= laptop_data[['screen_size',
       'hard_disk_size','cpu_model','special_feature', 'graphics_card_description',
       'graphics_coprocessor', 'series', 'card_description', 'color',
       'cpu_speed', 'hard_disk_description', 'resolution', 'rating','price']]
laptop_feature_dim['laptop_feature_id'] = laptop_feature_dim.index
laptop_feature_dim
# Out:
#     screen_size hard_disk_size                       cpu_model  \
# 0   15.6 Inches           1 TB                          Athlon
# 1   15.6 Inches           1 TB                   Pentium N5000
# 2   15.6 Inches         128 GB                         Celeron
# 3     14 Inches          64 GB                       Celeron N
# 4   15.6 Inches         512 GB                         Celeron
# 5   15.6 Inches           1 TB                          Athlon
# 6   15.6 Inches           1 TB                   Pentium N5000
# 7     14 Inches         256 GB                         Pentium
# 8   17.3 Inches         256 GB                   Ryzen 3 3250U
# 9     14 Inches         320 GB                   Celeron N4020
# 10    14 Inches         128 GB                         Pentium
# 11    14 Inches          64 GB                       Pentium D
# 12  11.6 Inches          32 GB                         Celeron
# 13    14 Inches         256 GB                  Core i5 Family
# 14  15.6 Inches         128 GB                   Pentium N5000
# 15  12.4 Inches         256 GB                  Core i5-1035G1
# 16    14 Inches         256 GB                   Intel Core i5
# 17  15.6 Inches         256 GB                         Core i3
# 18  15.6 Inches         512 GB                   Intel Core i5
# 19  13.3 Inches         256 GB                         Unknown
# 20  15.6 Inches         128 GB                  Core I3 1115G4
# 21  11.6 Inches          64 GB                       Pentium D
# 22  15.6 Inches           1 TB                   Ryzen 5 5500U
# 23  15.6 Inches           1 TB             Athlon Silver 3050U
# 24         11.6         128 GB                         Celeron
# 25    14 Inches          64 GB                   Celeron N4020
# 26  11.6 Inches            NaN                   Celeron N3450
# 27  15.6 Inches         128 GB  Mobile Intel Celeron Processor
# 28    14 Inches         256 GB                         Pentium
# 29  17.3 Inches           1 TB                  Core i3 Family
# 30  17.3 Inches         128 GB                         Celeron
# 31    14 Inches          64 GB                   Celeron N4020
# 32  15.6 Inches           1 TB                          Athlon
#
#                                       special_feature  \
# 0                                          Anti-glare
# 1                                  Anti Glare Coating
# 2                                                 NaN
# 3                                          Anti-glare
# 4                                                 NaN
# 5                                          Anti-glare
# 6                                  Anti Glare Coating
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                  Anti-glare Screen
# 14                                 Anti Glare Coating
# 15                           Fingerprint Power Button
# 16                                         Anti-glare
# 17                                 Anti Glare Coating
# 18                                            Full Hd
# 19                                   Backlit Keyboard
# 20                                       Amazon Alexa
# 21                                 Anti Glare Coating
# 22  Fingerprint Reader, HD Audio, Numeric Keypad, ...
# 23                                                NaN
# 24                                 Anti Glare Coating
# 25                                         Integrated
# 26                                 Anti Glare Coating
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                         Anti-glare
#
#    graphics_card_description           graphics_coprocessor  \
# 0                 Integrated            AMD Radeon Graphics
# 1                        NaN             Intel UHD Graphics
# 2                        NaN                     Integrated
# 3                        NaN                            NaN
# 4                        NaN                     Integrated
# 5                        NaN            AMD Radeon Graphics
# 6                 Integrated             Intel UHD Graphics
# 7                 Integrated             Intel UHD Graphics
# 8                        NaN           AMD Radeon™ Graphics
# 9                 Integrated         Intel UHD Graphics 600
# 10                       NaN                            NaN
# 11                       NaN                          Intel
# 12                Integrated                       Mediatek
# 13                Integrated                            NaN
# 14                Integrated                            NaN
# 15                Integrated                            NaN
# 16                       NaN                            NaN
# 17                       NaN                            NaN
# 18                       NaN                            NaN
# 19                Integrated                            NaN
# 20                Integrated                            NaN
# 21                Integrated                            NaN
# 22                       NaN                            NaN
# 23                Integrated            AMD Radeon Graphics
# 24                Integrated                            NaN
# 25                       NaN                            NaN
# 26                Integrated  Intel Celeron Processor N4000
# 27                Integrated                          Intel
# 28                Integrated             Intel UHD Graphics
# 29                Integrated             Intel UHD Graphics
# 30                Integrated                     Integrated
# 31                Integrated                     Integrated
# 32                Integrated            AMD Radeon graphics
#
#                       series card_description           color cpu_speed  \
# 0                        NaN              NaN             NaN       NaN
# 1                   Pavilion       Integrated             NaN       NaN
# 2                        NaN       Integrated            Gray   2.5 GHz
# 3                         HP       Integrated            Pink       NaN
# 4                        NaN       Integrated             NaN   2.9 GHz
# 5                    IdeaPad       Integrated             NaN       NaN
# 6                        NaN              NaN             NaN       NaN
# 7                        NaN              NaN             NaN   3.1 GHz
# 8                Pavilion 17       Integrated          Silver       NaN
# 9                        NaN              NaN             NaN   2.8 GHz
# 10               14-DQ3025CL       Integrated  Natural silver   3.3 GHz
# 11                Chromebook       Integrated  Mineral Silver       NaN
# 12                       NaN              NaN            Grey       NaN
# 13                       NaN              NaN           Black       NaN
# 14                       NaN              NaN             Red       NaN
# 15                       NaN              NaN        Platinum       NaN
# 16            Latitude E7470       Integrated           Black       NaN
# 17      IdeaPad 3 81X800ENUS       Integrated          Almond       NaN
# 18  Chromebook Vibe C55 Flip       Integrated    Mineral Grey       NaN
# 19                       NaN              NaN            Gold       NaN
# 20                       NaN              NaN          Silver       NaN
# 21                       NaN              NaN            Blue       NaN
# 22        ThinkBook 15 Gen 3       Integrated    Mineral Grey       NaN
# 23                       NaN              NaN            Gray   2.3 GHz
# 24                       NaN              NaN      Star Black       NaN
# 25         Lenovo Ideapad 1i              NaN            Gray       NaN
# 26                       NaN              NaN      Satin Gray       NaN
# 27                       NaN              NaN            Blue       NaN
# 28                       NaN              NaN             NaN   3.1 GHz
# 29                       NaN              NaN          Silver       NaN
# 30                       NaN              NaN            Gray   2.5 GHz
# 31                       NaN              NaN           White   1.1 GHz
# 32                       NaN              NaN             NaN       NaN
#
#    hard_disk_description resolution  \
# 0                    NaN        NaN
# 1                    NaN        NaN
# 2                    NaN        NaN
# 3                    NaN        NaN
# 4                    SSD      1080p
# 5                    NaN        NaN
# 6                    NaN        NaN
# 7                    SSD        NaN
# 8                    NaN        NaN
# 9                    NaN        NaN
# 10                   NaN        NaN
# 11                   NaN        NaN
# 12                   NaN        NaN
# 13                   NaN        NaN
# 14                   NaN        NaN
# 15                   NaN        NaN
# 16                   NaN        NaN
# 17                   NaN        NaN
# 18                   NaN        NaN
# 19                   NaN        NaN
# 20                   NaN        NaN
# 21                   NaN        NaN
# 22                   NaN        NaN
# 23                   NaN        NaN
# 24                   NaN        NaN
# 25                   NaN        NaN
# 26                   NaN        NaN
# 27                   NaN        NaN
# 28                   SSD        NaN
# 29                   NaN        NaN
# 30                   NaN        NaN
# 31                   NaN        NaN
# 32                   NaN        NaN
#
#                                          rating    price  laptop_feature_id
# 0                            4.3 out of 5 stars  $429.00                  0
# 1                            4.3 out of 5 stars  $469.00                  1
# 2                            4.4 out of 5 stars  $259.98                  2
# 3                            4.2 out of 5 stars  $259.99                  3
# 4                            4.3 out of 5 stars  $359.99                  4
# 5                            4.3 out of 5 stars  $429.00                  5
# 6                            4.3 out of 5 stars  $469.00                  6
# 7                            4.4 out of 5 stars  $209.99                  7
# 8                            4.3 out of 5 stars  $599.99                  8
# 9                            4.0 out of 5 stars  $199.00                  9
# 10                           4.8 out of 5 stars  $161.00                 10
# 11                           4.4 out of 5 stars  $124.00                 11
# 12                           4.6 out of 5 stars  $228.00                 12
# 13                           4.1 out of 5 stars  $152.95                 13
# 14                           4.4 out of 5 stars  $199.99                 14
# 15                           4.5 out of 5 stars  $544.00                 15
# 16                           4.2 out of 5 stars  $129.89                 16
# 17                           4.3 out of 5 stars  $421.00                 17
# 18  Previous page of related Sponsored Products  $699.99                 18
# 19                           4.8 out of 5 stars  $799.99                 19
# 20                           4.3 out of 5 stars  $299.99                 20
# 21                           3.9 out of 5 stars  $129.00                 21
# 22                           4.9 out of 5 stars  $729.99                 22
# 23                           4.3 out of 5 stars  $369.00                 23
# 24                           3.8 out of 5 stars  $189.99                 24
# 25                           4.1 out of 5 stars  $163.88                 25
# 26                           4.4 out of 5 stars  $138.85                 26
# 27                           3.9 out of 5 stars  $139.99                 27
# 28                           4.4 out of 5 stars  $209.99                 28
# 29                           5.0 out of 5 stars  $598.00                 29
# 30                           4.2 out of 5 stars  $299.99                 30
# 31                           4.3 out of 5 stars  $288.99                 31
# 32                           3.8 out of 5 stars  $399.00                 32

# %%
Ram_dim =laptop_data[['ram_memory_installed_size']].drop_duplicates().reset_index(drop= True)
Ram_dim['Ram_os_id'] = Ram_dim.index
print(Ram_dim)
os_dim = laptop_data[['operating_system']].drop_duplicates().reset_index(drop= True)
os_dim['os_id'] = os_dim.index
os_dim
# Out:
#   ram_memory_installed_size  Ram_os_id
# 0                     20 GB          0
# 1                     16 GB          1
# 2                      4 GB          2
# 3                     12 GB          3
# 4                      8 GB          4
# 5                     32 GB          5
#    operating_system  os_id
# 0        Windows 11      0
# 1      Windows 10 S      1
# 2               NaN      2
# 3      Windows 11 S      3
# 4        Windows 10      4
# 5   Windows 11 Home      5
# 6         Chrome OS      6
# 7    Windows 10 Pro      7
# 8   Windows 10 Home      8
# 9            Mac OS      9
# 10   Windows 11 Pro     10

# %%
fact_details1 = laptop_data.merge(Laptop_Name_dim, on = 'title')\
                  .merge(os_dim, on = 'operating_system')\
                  .merge(Ram_dim, on = 'ram_memory_installed_size')\
                  .merge(laptop_feature_dim, on = ['screen_size',
       'hard_disk_size','cpu_model','special_feature', 'graphics_card_description',
       'graphics_coprocessor', 'series', 'card_description', 'color',
       'cpu_speed', 'hard_disk_description', 'resolution', 'rating','price'])\
        [['Laptop_Name_id','os_id','Ram_os_id','laptop_feature_id','price']]
fact_details1['id'] = fact_details1.index
fact_details1
# Out:
#     Laptop_Name_id  os_id  Ram_os_id  laptop_feature_id    price  id
# 0                0      0          0                  0  $429.00   0
# 1                5      0          0                  0  $429.00   1
# 2                0      0          0                  5  $429.00   2
# 3                5      0          0                  5  $429.00   3
# 4               17      0          0                 17  $421.00   4
# 5               23      3          0                 23  $369.00   5
# 6               32      3          0                 32  $399.00   6
# 7                1      0          1                  1  $469.00   7
# 8                6      0          1                  1  $469.00   8
# 9                1      0          1                  6  $469.00   9
# 10               6      0          1                  6  $469.00  10
# 11               8      4          1                  8  $599.99  11
# 12              18      6          1                 18  $699.99  12
# 13              13      7          1                 13  $152.95  13
# 14               2      0          2                  2  $259.98  14
# 15               9      0          2                  9  $199.00  15
# 16              25      0          2                 25  $163.88  16
# 17              27      0          2                 27  $139.99  17
# 18              30      0          2                 30  $299.99  18
# 19               3      1          2                  3  $259.99  19
# 20              21      1          2                 21  $129.00  20
# 21               7      3          2                  7  $209.99  21
# 22               7      3          2                 28  $209.99  22
# 23              28      3          2                  7  $209.99  23
# 24              28      3          2                 28  $209.99  24
# 25               7      3          2                  7  $209.99  25
# 26               7      3          2                 28  $209.99  26
# 27              28      3          2                  7  $209.99  27
# 28              28      3          2                 28  $209.99  28
# 29              24      3          2                 24  $189.99  29
# 30              10      5          2                 10  $161.00  30
# 31              11      6          2                 11  $124.00  31
# 32              12      6          2                 12  $228.00  32
# 33              26      6          2                 26  $138.85  33
# 34              14      8          2                 14  $199.99  34
# 35              15      1          4                 15  $544.00  35
# 36              31      1          4                 31  $288.99  36
# 37              20      3          4                 20  $299.99  37
# 38              16      7          4                 16  $129.89  38
# 39              19      9          4                 19  $799.99  39
# 40               4      2          3                  4  $359.99  40
# 41              29      5          5                 29  $598.00  41
# 42              22     10          5                 22  $729.99  42

# %%
 Laptop_Name_dim = laptop_data[['title','brand', 'model_name']]
    Laptop_Name_dim['Laptop_Name_id'] = Laptop_Name_dim.index

    laptop_feature_dim= laptop_data[['screen_size',
       'hard_disk_size','cpu_model','special_feature', 'graphics_card_description',
       'graphics_coprocessor', 'series', 'card_description', 'color',
       'cpu_speed', 'hard_disk_description', 'resolution', 'rating','price']]
    laptop_feature_dim['laptop_feature_id'] = laptop_feature_dim.index

    Ram_dim =laptop_data[['ram_memory_installed_size']].drop_duplicates().reset_index(drop= True)
    Ram_dim['Ram_os_id'] = Ram_dim.index

    os_dim = laptop_data[['operating_system']].drop_duplicates().reset_index(drop= True)
    os_dim['os_id'] = os_dim.index

    fact_details1 = laptop_data.merge(Laptop_Name_dim, on = 'title')\
                  .merge(os_dim, on = 'operating_system')\
                  .merge(Ram_dim, on = 'ram_memory_installed_size')\
                  .merge(laptop_feature_dim, on = ['screen_size',
       'hard_disk_size','cpu_model','special_feature', 'graphics_card_description',
       'graphics_coprocessor', 'series', 'card_description', 'color',
       'cpu_speed', 'hard_disk_description', 'resolution', 'rating','price'])\
        [['Laptop_Name_id','os_id','Ram_os_id','laptop_feature_id','price']]
    fact_details1['id'] = fact_details1.index

    print(fact_details1)
    return {"Laptop_Name_dim":Laptop_Name_dim.to_dict(orient = "dict"),
    "laptop_feature_dim":laptop_feature_dim.to_dict(orient = "dict"),
    "Ram_dim":Ram_dim.to_dict(orient = "dict"),
    "os_dim":os_dim.to_dict(orient = "dict"),
    "fact_details1":fact_details1.to_dict(orient = "dict")}
